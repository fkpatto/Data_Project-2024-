# %% [markdown]
# # Pandas Visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\Cigar\Documents\Sales_sample.csv")
df = df.set_index('Region')
df
# Out:
#         OrderDate       Rep     Item  Units  Unit Cost    Total
# Region
# East       1/6/21     Jones   Pencil     95       1.99   189.05
# Central   1/23/21    Kivell   Binder     50      19.99   999.50
# Central    2/9/21   Jardine   Pencil     36       4.99   179.64
# Central   2/26/21      Gill      Pen     27      19.99   539.73
# West      3/15/21   Sorvino   Pencil     56       2.99   167.44
# East       4/1/21     Jones   Binder     60       4.99   299.40
# Central   4/18/21   Andrews   Pencil     75       1.99   149.25
# Central    5/5/21   Jardine   Pencil     90       4.99   449.10
# West      5/22/21  Thompson   Pencil     32       1.99    63.68
# East       6/8/21     Jones   Binder     60       8.99   539.40
# Central   6/25/21    Morgan   Pencil     90       4.99   449.10
# East      7/12/21    Howard   Binder     29       1.99    57.71
# East      7/29/21    Parent   Binder     81      19.99  1619.19
# East      8/15/21     Jones   Pencil     35       4.99   174.65
# ...

# %%
freddy = df.drop_duplicates()
print(freddy)
# Out:
#         OrderDate       Rep     Item  Units  Unit Cost    Total
# Region
# East       1/6/21     Jones   Pencil     95       1.99   189.05
# Central   1/23/21    Kivell   Binder     50      19.99   999.50
# Central    2/9/21   Jardine   Pencil     36       4.99   179.64
# Central   2/26/21      Gill      Pen     27      19.99   539.73
# West      3/15/21   Sorvino   Pencil     56       2.99   167.44
# East       4/1/21     Jones   Binder     60       4.99   299.40
# Central   4/18/21   Andrews   Pencil     75       1.99   149.25
# Central    5/5/21   Jardine   Pencil     90       4.99   449.10
# West      5/22/21  Thompson   Pencil     32       1.99    63.68
# East       6/8/21     Jones   Binder     60       8.99   539.40
# Central   6/25/21    Morgan   Pencil     90       4.99   449.10
# East      7/12/21    Howard   Binder     29       1.99    57.71
# East      7/29/21    Parent   Binder     81      19.99  1619.19
# East      8/15/21     Jones   Pencil     35       4.99   174.65
# ...

# %%
freddy.plot(kind = 'line', title = 'Sales_sample', xlabel = 'Daily Ratings', ylabel = 'Scores')
# Out:
# <Axes: title={'center': 'Sales_sample'}, xlabel='Daily Ratings', ylabel='Scores'>

# %%
freddy.plot.bar(stacked = True)
# Out:
# <Axes: xlabel='Region'>

# %%
freddy.plot.scatter(x = 'Rep', y = 'Units', c = 'blue')
# Out:
# <Axes: xlabel='Rep', ylabel='Units'>

# %%
freddy.plot.hist(bins = 10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
freddy.boxplot()
# Out:
# <Axes: >

# %%
freddy.plot.area(figsize = (10,5))
# Out:
# <Axes: xlabel='Region'>

# %%
df.plot.pie(y='Units',figsize=(10,10))
# Out:
# <Axes: ylabel='Units'>
